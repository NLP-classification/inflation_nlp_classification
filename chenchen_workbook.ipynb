# %%
import re
import unicodedata
import pandas as pd
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('inflation_readme.csv', index_col=0)
df.head()
# Out:
#                                     repo language  \
# 0                cashapp/InflationInject   Kotlin
# 1                    InflationX/ViewPump   Kotlin
# 2                     rdeits/iris-distro   Matlab
# 3  uhussain/WebCrawlerForOnlineInflation   Python
# 4                          sandes/zipfly   Python
#
#                                      readme_contents
# 0  # Inflation Injection\n\nConstructor-inject vi...
# 1  ViewPump\n========\n\nView inflation you can i...
# 2  Introduction\n============\n\nThis package con...
# 3  # Table of Contents \n1. [Introduction](README...
# 4  [![Build Status](https://img.shields.io/circle...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 848 entries, 0 to 847
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   repo             848 non-null    object
#  1   language         727 non-null    object
#  2   readme_contents  611 non-null    object
# dtypes: object(3)
# memory usage: 26.5+ KB

# %%
df.isnull().sum()
# Out:
# repo                 0
# language           121
# readme_contents    237
# dtype: int64

# %%
df[df.readme_contents.isnull()]
# Out:
#                                     repo          language readme_contents
# 17      future-tense/pool.futuretense.io              HTML             NaN
# 19                       gwern/gwern.net           Haskell             NaN
# 55        kranthikittu/Android_inflation            Kotlin             NaN
# 60            itamarcaspi/core-inflation              HTML             NaN
# 67      motherjones/inflation-calculator               NaN             NaN
# ..                                   ...               ...             ...
# 842    LUNDR/inflation_forecasts_with_tf  Jupyter Notebook             NaN
# 843           millerngit/RateOfInflation               C++             NaN
# 844  iamdingkai/what-s-driving-inflation  Jupyter Notebook             NaN
# 846     fscheler/Inflation_Tracker_World              HTML             NaN
# 847     jacobrosen1997/ECON323-Inflation  Jupyter Notebook             NaN
#
# [237 rows x 3 columns]

# %%
# drop the null value

# %%
df = df.dropna()
df.shape
# Out:
# (523, 3)

# %% [markdown]
# ### Prepare

# %%
def basic_clean(text):
    article = text.lower()
    article = unicodedata.normalize('NFKD', article)\
    .encode('ascii', 'ignore')\
    .decode('utf-8', 'ignore')
    article = re.sub(r"[^a-z0-9'\s]", '', article)
    return article

# %%
def tokenize(basic_clean_text):
    tokenizer = nltk.tokenize.ToktokTokenizer()
    article = tokenizer.tokenize(basic_clean_text, return_str=True)
    return article

# %%
def stem(tokenized_text):
    ps = nltk.stem.porter.PorterStemmer()
    stems = [ps.stem(word) for word in tokenized_text.split()]
    article_stemmed = ' '.join(stems)
    return article_stemmed

# %%
def lemmatize(tokenized_text):    
    wnl = nltk.stem.WordNetLemmatizer()    
    lemmas = [wnl.lemmatize(word) for word in tokenized_text.split()]    
    lemmatized_string = ' '.join(lemmas)    
    return lemmatized_string

# %%
def remove_stopwords(string, extra_words=None, exclude_words=None):    
    stopword_list = stopwords.words('english')    
    if exclude_words:        
        stopword_list = stopword_list + exclude_words
        
    if extra_words:        
        for word in extra_words:            
            stopword_list.remove(word)
            
    words = string.split()    
    filtered_words = [word for word in words if word not in stopword_list]    
    filtered_string = ' '.join(filtered_words)   
    return filtered_string

# no_stop = remove_stopwords(lemmatized)

# %%
# extra_words = ['the','no']
# no_stop1 = remove_stopwords(lemmatized, extra_words=extra_words)
# no_stop1

# %%
df['clean'] = df['readme_contents'].apply(basic_clean).apply(tokenize).apply(remove_stopwords)
df['stemmed'] = df['clean'].apply(stem)
df['lemmatized'] = df['clean'].apply(lemmatize)
df.head()
# Out:
#                                     repo language  \
# 0                cashapp/InflationInject   Kotlin
# 1                    InflationX/ViewPump   Kotlin
# 2                     rdeits/iris-distro   Matlab
# 3  uhussain/WebCrawlerForOnlineInflation   Python
# 4                          sandes/zipfly   Python
#
#                                      readme_contents  \
# 0  # Inflation Injection\n\nConstructor-inject vi...
# 1  ViewPump\n========\n\nView inflation you can i...
# 2  Introduction\n============\n\nThis package con...
# 3  # Table of Contents \n1. [Introduction](README...
# 4  [![Build Status](https://img.shields.io/circle...
#
#                                                clean  \
# 0  inflation injection constructorinject views xm...
# 1  viewpump view inflation intercept viewpump ins...
# 2  introduction package contains iris algorithm i...
# 3  table contents 1 introductionreadmemdintroduct...
# 4  build statushttpsimgshieldsiocirclecibuildgith...
#
#                                              stemmed  \
# 0  inflat inject constructorinject view xml layou...
# 1  viewpump view inflat intercept viewpump instal...
# 2  introduct packag contain iri algorithm iter co...
# 3  tabl content 1 introductionreadmemdintroduct 2...
# 4  build statushttpsimgshieldsiocirclecibuildgith...
#
#                                           lemmatized
# 0  inflation injection constructorinject view xml...
# 1  viewpump view inflation intercept viewpump ins...
# 2  introduction package contains iris algorithm i...
# 3  table content 1 introductionreadmemdintroducti...
# 4  build statushttpsimgshieldsiocirclecibuildgith...

# %%
df.language.value_counts().head(10)
# Out:
# Python              102
# Jupyter Notebook     96
# JavaScript           61
# R                    55
# HTML                 46
# Java                 24
# C++                  13
# TypeScript           13
# CSS                  10
# TeX                   9
# Name: language, dtype: int64

# %%
df =  df.astype('string')

# %%
df[df.language == 'Jupyter Notebook']
# Out:
#                                                  repo          language  \
# 9                                        palewire/cpi  Jupyter Notebook
# 22           fipelle/replication-hasenzagl-et-al-2020  Jupyter Notebook
# 26                                      rsvp/fecon235  Jupyter Notebook
# 59                         koksoya/inflation-forecast  Jupyter Notebook
# 88                                  fqroldan/Conquest  Jupyter Notebook
# ..                                                ...               ...
# 826           Manu-Gr/Project---Forecasting-Inflation  Jupyter Notebook
# 827  longjivwamhi/Fandango-Ratings-Inflation-Analysis  Jupyter Notebook
# 829                     kassiili/two-period-inflation  Jupyter Notebook
# 838                       lowsaelee/us-inflation-data  Jupyter Notebook
# 839          HodanYusuf9/Visualize-Inflation-for-2019  Jupyter Notebook
#
#                                        readme_contents  \
# 9    ### Links
#
# * Docs: [palewi.re/docs/cpi/](https...
# 22   ## A Model of the Fed's View on Inflation
#
# Thi...
# 26   ## fecon235 :: Notebooks for financial economi...
# 59   # inflation-forecast
#
# ## Objectives of the Pro...
# 88   # Conquest
# Jupyter Notebooks replication of Th...
# ..                                                 ...
# 826  # Project---Forecasting-Inflation
#
# * Analysing...
# 827              # Fandango-Ratings-Inflation-Analysis
# 829  # two-period-inflation
#
# This code was used to ...
# 838  # us-inflation-data
#
# Data source: https://www....
# 839  # Visualize Inflation for 2019
#
# we will visual...
#
#                                                  clean  \
# 9    links docs palewiredocscpihttpspalewiredocscpi...
# 22   model fed ' view inflation repository contains...
# 26   fecon235 notebooks financial economics join ch...
# 59   inflationforecast objectives project define in...
# 88   conquest jupyter notebooks replication conques...
# ..                                                 ...
# 826  projectforecastinginflation analysing inflatio...
# 827                   fandangoratingsinflationanalysis
# 829  twoperiodinflation code used analyse nparticle...
# 838  usinflationdata data source httpswwwkagglecomv...
# 839  visualize inflation 2019 visualize inflation m...
#
#                                                stemmed  \
# 9    link doc palewiredocscpihttpspalewiredocscpi c...
# 22   model fed ' view inflat repositori contain sou...
# 26   fecon235 notebook financi econom join chat htt...
# 59   inflationforecast object project defin inflat ...
# 88   conquest jupyt notebook replic conquest americ...
# ..                                                 ...
# 826  projectforecastinginfl analys inflat trend his...
# 827                    fandangoratingsinflationanalysi
# 829  twoperiodinfl code use analys nparticl simul t...
# 838  usinflationdata data sourc httpswwwkagglecomva...
# 839  visual inflat 2019 visual inflat map done get ...
#
#                                             lemmatized
# 9    link doc palewiredocscpihttpspalewiredocscpi c...
# 22   model fed ' view inflation repository contains...
# 26   fecon235 notebook financial economics join cha...
# 59   inflationforecast objective project define inf...
# 88   conquest jupyter notebook replication conquest...
# ..                                                 ...
# 826  projectforecastinginflation analysing inflatio...
# 827                   fandangoratingsinflationanalysis
# 829  twoperiodinflation code used analyse nparticle...
# 838  usinflationdata data source httpswwwkagglecomv...
# 839  visualize inflation 2019 visualize inflation m...
#
# [96 rows x 6 columns]

# %% [markdown]
# ### only pick top 5 to predict

# %%
ADDITIONAL_STOPWORDS = []

def clean(text):
    'A simple function to cleanup data'
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english') + ADDITIONAL_STOPWORDS
    text = (unicodedata.normalize('NFKD', text)
             .encode('ascii', 'ignore')
             .decode('utf-8', 'ignore')
             .lower())
    words = re.sub(r'[^\w\s]', '', text).split()
    return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
python_words = clean(' '.join(df[df.language == 'Python'].readme_contents))
jupyter_notebook_words = clean(' '.join(df[df.language == 'Jupyter Notebook'].readme_contents))
javascript_words = clean(' '.join(df[df.language == 'JavaScript'].readme_contents))
r_words = clean(' '.join(df[df.language == 'R'].readme_contents))
html_words = clean(' '.join(df[df.language == 'HTML'].readme_contents))
all_words = clean(' '.join(df.readme_contents))

# %%
python_words
# Out:
# ['table',
#  'content',
#  '1',
#  'introductionreadmemdintroduction',
#  '2',
#  'pipelinereadmemdpipeline',
#  '3',
#  'requirementsreadmemdrequirements',
#  '4',
#  'environment',
#  'set',
#  'upreadmemdenvironment20setup',
#  '5',
#  'repository',
#  'structure',
#  'run',
#  'instructionsreadmemdrepository20structure20and20run20instructions',
#  'introduction',
#  'price',
#  'crawler',
#  'tracking',
#  'price',
#  'inflation',
#  'project',
#  'completed',
#  '3',
#  'week',
#  'insight',
#  'data',
#  'engineering',
#  'program',
#  'new',
#  'york',
#  '20b',
#  'session',
#  'goal',
#  'project',
#  'calculate',
#  'inflation',
#  'rate',
#  'first',
#  'principle',
#  'mean',
#  'calculating',
#  'inflation',
#  'rate',
#  'using',
#  'price',
#  'good',
#  'service',
#  'sold',
#  'online',
#  'project',
#  'built',
#  'pipleine',
#  'use',
#  'petabyte',
#  'web',
#  'page',
#  'data',
#  'contained',
#  'common',
#  'crawlhttpscommoncrawlorg',
#  'archive',
#  'web',
#  'page',
#  'content',
#  'calculate',
#  'inflation',
#  'rate',
#  'result',
#  'used',
#  'enhance',
#  'investment',
#  'strategy',
#  'business',
#  'deciding',
#  'cost',
#  'product',
#  'sample',
#  'batch',
#  'job',
#  'executed',
#  'using',
#  'online',
#  'laptop',
#  'price',
#  '500800',
#  'inflation',
#  'rate',
#  '2019',
#  'measured',
#  '48',
#  'double',
#  'annual',
#  'inflation',
#  'rate',
#  '23',
#  'reported',
#  'bureau',
#  'labor',
#  'statistic',
#  '2019',
#  'recording',
#  'webui',
#  'also',
#  'available',
#  'herehttpswwwyoutubecomwatchvmncodsh5254featureyoutube',
#  'pipeline',
#  'built',
#  'data',
#  'pipeline',
#  'utilizes',
#  'petabyte',
#  'publicly',
#  'available',
#  'web',
#  'page',
#  'data',
#  'calculate',
#  'inflation',
#  'rate',
#  'first',
#  'principle',
#  'price',
#  'product',
#  'pipelinestaticcrawler_pipelinepng',
#  '1',
#  'aws',
#  'athena',
#  'query',
#  'indexed',
#  'warc',
#  'file',
#  'using',
#  'http',
#  'header',
#  'information',
#  'warc',
#  'file',
#  'scan',
#  '0100',
#  'gb',
#  'data',
#  'instead',
#  'pb',
#  '2',
#  'key',
#  'webpage',
#  'interest',
#  'saved',
#  'parquet',
#  'file',
#  's3',
#  '3',
#  'parquet',
#  'warc',
#  'input',
#  'spark',
#  'distributed',
#  'processing',
#  'o10',
#  'gb',
#  'data',
#  'per',
#  'job',
#  '4',
#  'cleaning',
#  'filtering',
#  'aggregating',
#  'product',
#  'price',
#  'table',
#  'panda',
#  'python',
#  '5',
#  'plotting',
#  'tracking',
#  'price',
#  'trend',
#  'dash',
#  'requirement',
#  '1',
#  's3',
#  'set',
#  's3',
#  'bucket',
#  'case',
#  's3athenaeast2usama',
#  '2',
#  'athena',
#  'open',
#  'athena',
#  'aws',
#  'follow',
#  'instruction',
#  'set',
#  'running',
#  'sql',
#  'query',
#  'athena',
#  'httpscommoncrawlorg201803indextowarcfilesandurlsincolumnarformat',
#  '3',
#  'run',
#  'athena',
#  'example',
#  'httpsgithubcomuhussainwebcrawlerforonlineinflationathenaathena_instructionstxt',
#  '4',
#  'start',
#  'emr',
#  'amazon',
#  'spark',
#  'hadoop',
#  'ssh',
#  '5',
#  'add',
#  'following',
#  'bashrc',
#  'source',
#  'bashrc',
#  'export',
#  'spark_homeusrlibspark',
#  'export',
#  'pythonpathspark_homepythonlibpy4j0107srczippythonpath',
#  'export',
#  'pythonpathspark_homepythonspark_homepythonbuildpythonpath',
#  '6',
#  'install',
#  'following',
#  'emr',
#  'master',
#  'worker',
#  'pip',
#  'install',
#  'user',
#  'warcio',
#  'boto3',
#  'bs4',
#  'nltk',
#  '7',
#  'execute',
#  'mainpy',
#  'master',
#  'node',
#  'language',
#  'bash',
#  'python',
#  '37',
#  'panda',
#  'technology',
#  'spark',
#  'aws',
#  'athena',
#  'dashplotly',
#  'thirdparty',
#  'library',
#  'aws',
#  'cli',
#  'environment',
#  'setup',
#  'install',
#  'configure',
#  'awshttpsawsamazoncomcli',
#  'opensource',
#  'tool',
#  'setup',
#  'aws',
#  'emr',
#  'cluster',
#  'launch',
#  'time',
#  'emr5300',
#  'version',
#  'used',
#  'come',
#  'python',
#  'version',
#  '376',
#  'pyspark',
#  'version',
#  '245amzn0',
#  'zeppelin',
#  '082',
#  'aws',
#  'emr',
#  'cluster',
#  'setup',
#  'currently',
#  'using',
#  'one',
#  'master',
#  'node',
#  'two',
#  'core',
#  'node',
#  'scaled',
#  'repository',
#  'structure',
#  'run',
#  'instruction',
#  'athena',
#  'contains',
#  'instruction',
#  'query',
#  'common',
#  'crawl',
#  'data',
#  'aws',
#  'athena',
#  'spark',
#  'contains',
#  'mainpy',
#  'spark',
#  'script',
#  'launch',
#  'spark',
#  'job',
#  'using',
#  'output',
#  'athena',
#  'query',
#  'sparksubmit',
#  'sparkmainpy',
#  'walmart_laptops_2018',
#  'walmart_parquet_2018',
#  'pandascontains',
#  'python',
#  'script',
#  'clean',
#  'output',
#  'spark',
#  'provide',
#  'csv',
#  'file',
#  'dashappapppy',
#  'python3',
#  'pandascleanerpy',
#  'dashapp',
#  'contains',
#  'dash',
#  'app',
#  'visualize',
#  'trend',
#  'online',
#  'price',
#  'laptop',
#  'across',
#  'time',
#  'python3',
#  'dashappprice_trackerpy',
#  'development',
#  'work',
#  'built',
#  'rapid',
#  'prototype',
#  'pipeline',
#  'first',
#  'week',
#  'understand',
#  'scope',
#  'problem',
#  'learn',
#  'textual',
#  'html',
#  'content',
#  'analysis',
#  'ingested',
#  'data',
#  'aws',
#  's3',
#  'cleaned',
#  'filtered',
#  'singlethreaded',
#  'python',
#  'script',
#  'aggregated',
#  'product',
#  'information',
#  'local',
#  'amazon',
#  'dyanmodb',
#  'database',
#  'prototype',
#  'contains',
#  'python',
#  'configuration',
#  'file',
#  'script',
#  'running',
#  'project',
#  'locally',
#  'output',
#  'product',
#  'info',
#  'local',
#  'amazon',
#  'dynamodb',
#  'table',
#  'language',
#  'bash',
#  'python',
#  '37',
#  'technology',
#  'amazon',
#  'dynamodb',
#  'build',
#  'statushttpsimgshieldsiocirclecibuildgithubsandeszipflymasterhttpsappcirclecicompipelinesgithubsandeszipfly',
#  'github',
#  'release',
#  'latest',
#  'datehttpsimgshieldsiogithubvreleasebuzoniozipfly',
#  'downloadshttpspepytechbadgezipflyhttpspepytechprojectzipfly',
#  'zipfly',
#  'zipfly',
#  'zip',
#  'archive',
#  'generator',
#  'based',
#  'zipfilepy',
#  'created',
#  'hrefhttpssantiagodebuscom',
#  'targetblanksantiago',
#  'debusa',
#  'generate',
#  'large',
#  'zip',
#  'archive',
#  'immediate',
#  'sending',
#  'client',
#  'writing',
#  'large',
#  'zip',
#  'archive',
#  'without',
#  'memory',
#  'inflation',
#  'requirement',
#  'python',
#  '36',
#  'added',
#  'hrefhttpsdocspythonorg3libraryzipfilehtmlzipfileobjects',
#  'targetblanksupporta',
#  'writing',
#  'unseekable',
#  'stream',
#  'install',
#  'pip3',
#  'install',
#  'zipfly',
#  'basic',
#  'usage',
#  'compress',
#  'onthefly',
#  'writes',
#  'using',
#  'library',
#  'save',
#  'write',
#  'zip',
#  'disk',
#  'data',
#  'buffered',
#  'zipfile',
#  'deflater',
#  'memory',
#  'inflation',
#  'going',
#  'constrained',
#  'data',
#  'written',
#  'destination',
#  'default',
#  'regular',
#  '32kb',
#  'interval',
#  'zipfly',
#  'default',
#  'attributesbr',
#  'bpathsb',
#  'br',
#  'bmodeb',
#  'write',
#  'w',
#  'br',
#  'bchunksizeb',
#  'byte',
#  '32768',
#  'br',
#  'bcompressionb',
#  'stored',
#  'br',
#  'ballowzip64b',
#  'true',
#  'br',
#  'bcompresslevelb',
#  'none',
#  'br',
#  'bstoresizeb',
#  'byte',
#  '0',
#  'br',
#  'bencodeb',
#  'utf8',
#  'br',
#  'br',
#  'path',
#  'blist',
#  'dictionariesb',
#  'f',
#  'path',
#  'file',
#  'filesystem',
#  'n',
#  'optional',
#  'name',
#  'within',
#  'archive',
#  'br',
#  'default',
#  'f',
#  'br',
#  'python',
#  'import',
#  'zipfly',
#  'path',
#  'f',
#  'pathtolargefile',
#  'zfly',
#  'zipflyzipflypaths',
#  'path',
#  'generator',
#  'zflygenerator',
#  'print',
#  'generator',
#  'generator',
#  'object',
#  'zipflygenerator',
#  '0x7f74d52bcc50',
#  'openlargezip',
#  'wb',
#  'f',
#  'generator',
#  'fwritei',
#  'example',
#  'bstreaming',
#  'multiple',
#  'file',
#  'zip',
#  'hrefhttpsgithubcomsandeszipflyblobmasterexamplesstreaming_djangopy',
#  'target_blankdjangoa',
#  'hrefhttpsgithubcomsandeszipflyblobmasterexamplesstreaming_flaskpy',
#  'target_blankflaskab',
#  'send',
#  'forth',
#  'large',
#  'file',
#  'client',
#  'popular',
#  'framework',
#  'bcreate',
#  'pathsb',
#  'easy',
#  'way',
#  'create',
#  'array',
#  'path',
#  'parent',
#  'folder',
#  'bpredict',
#  'size',
#  'zip',
#  'file',
#  'creating',
#  'itb',
#  'use',
#  'bufferpredictionsize',
#  'compute',
#  'correct',
#  'size',
#  'resulting',
#  'archive',
#  'creating',
#  'bstreaming',
#  'large',
#  'fileb',
#  'efficient',
#  'way',
#  'read',
#  'single',
#  'large',
#  'binary',
#  'file',
#  'python',
#  'bset',
#  'commentb',
#  'comment',
#  'zip',
#  'file',
#  'maintainer',
#  'santiago',
#  'debus',
#  'hrefhttpsantiagodebuscom',
#  'target_blanksantiagodebuscomabr',
#  'license',
#  'library',
#  'created',
#  'buzonio',
#  'released',
#  'mit',
#  'copyright',
#  '2021',
#  'cardallot',
#  'inc',
#  'inflation',
#  'gdp',
#  'deflator',
#  'annual',
#  'inflation',
#  'consumer',
#  'price',
#  'annual',
#  'country',
#  'world',
#  'measured',
#  'data',
#  'data',
#  'come',
#  'world',
#  'bank',
#  'cpihttpapiworldbankorgindicatornygdpdeflkdzgformatcsv',
#  'world',
#  'bank',
#  'gdphttpapiworldbankorgindicatorfpcpitotlzgformatcsv',
#  'collected',
#  '1973',
#  '2014',
#  'value',
#  'missing',
#  'data',
#  'user',
#  'data',
#  'guess',
#  'empty',
#  'slot',
#  'actual',
#  'download',
#  'happens',
#  'via',
#  'world',
#  'bank',
#  'api',
#  'csv',
#  'requested',
#  'format',
#  'cpihttpapiworldbankorgindicatorfpcpitotlzgformatcsv',
#  'world',
#  'bank',
#  'api',
#  'csv',
#  'requested',
#  'format',
#  'gdphttpapiworldbankorgindicatornygdpdeflkdzgformatcsv',
#  'preparation',
#  'parsed',
#  'via',
#  'script',
#  'processpy',
#  'located',
#  'script',
#  'license',
#  'data',
#  'package',
#  'licensed',
#  'maintainer',
#  'public',
#  'domain',
#  'dedication',
#  'license',
#  'pddlhttpopendatacommonsorglicensespddl10',
#  'forecasting',
#  'cpi',
#  'inflation',
#  'hierarchical',
#  'recurrent',
#  'neural',
#  'network',
#  'repository',
#  'contains',
#  'implementation',
#  'novel',
#  'model',
#  'suggested',
#  'paper',
#  '1',
#  'hierarchical',
#  'gru',
#  'addition',
#  'contribution',
#  'research',
#  'provide',
#  'data',
#  'set',
#  'used',
#  'work',
#  'taken',
#  'bls',
#  'parsing',
#  'preprocessing',
#  'data',
#  'could',
#  'found',
#  'datacpi_us_datasetcsv',
#  'note',
#  'sample',
#  'data',
#  'brief',
#  'description',
#  'data',
#  'set',
#  'data',
#  'set',
#  'contains',
#  'following',
#  'column',
#  'date',
#  'differs',
#  'month',
#  'category',
#  'item',
#  'name',
#  'category',
#  'id',
#  'item',
#  'unique',
#  'id',
#  'price',
#  'seasonally',
#  'adjusted',
#  'cpiu',
#  'given',
#  'month',
#  'weight',
#  'relative',
#  'importance',
#  'item',
#  'total',
#  'aggregated',
#  'index',
#  '100',
#  'indent',
#  'hierarchy',
#  'level',
#  'total',
#  'aggregated',
#  'index',
#  'indent',
#  '0',
#  'lowest',
#  'level',
#  '8',
#  'parent',
#  'parent',
#  'item',
#  'name',
#  'parent',
#  'id',
#  'parent',
#  'item',
#  'id',
#  'order',
#  'run',
#  'code',
#  'please',
#  'make',
#  'sure',
#  'prerequisite',
#  'met',
#  'pandas022',
#  'particular',
#  'prerequisite',
#  'pip',
#  'install',
#  'r',
#  'requirementstxt',
#  'execute',
#  'code',
#  'please',
#  'run',
#  'one',
#  'following',
#  '1',
#  'hierarchical_grupy',
#  'monero',
#  'inflation',
#  'checker',
#  'work',
#  'mic',
#  'monero',
#  'inflation',
#  'checker',
#  'derivative',
#  'mininero',
#  'shennoether',
#  'httpsgithubcommoneroprojectmininero',
#  'dumb25519',
#  'sarangnoether',
#  'httpsgithubcomsarangnoetherskunkworkstreecurvesdumb25519',
#  'mic',
#  'monero',
#  'inflation',
#  'checker',
#  'licensed',
#  'gpl',
#  '30',
#  'dangerousfreedom',
#  'tldr',
#  'minimal',
#  'python',
#  'tool',
#  'educational',
#  'material',
#  'checking',
#  'inflation',
#  'monero',
#  'get',
#  'information',
#  'moneroinflationcomhttpswwwmoneroinflationcom',
#  'mic',
#  'offer',
#  'minimal',
#  'python',
#  'tool',
#  'check',
#  'transaction',
#  'emission',
#  'curve',
#  'ring',
#  'signature',
#  'zeroknowledge',
#  'proof',
#  'others',
#  'prove',
#  'inflation',
#  'happening',
#  'monero',
#  'tool',
#  'educational',
#  'purpose',
#  'ready',
#  'production',
#  'installation',
#  'requirement',
#  'please',
#  'install',
#  'required',
#  'package',
#  'inside',
#  'new',
#  'virtual',
#  'environment',
#  'python3',
#  'venv',
#  'vmic',
#  'source',
#  'vmicbinactivate',
#  'pip',
#  'install',
#  'r',
#  'requirementstxt',
#  'two',
#  'option',
#  'use',
#  'mic',
#  'verifier',
#  '1',
#  'using',
#  'full',
#  'node',
#  'standard',
#  'connection',
#  'parameter',
#  'usernamepassword',
#  'usernamepassword',
#  'rpc_connection',
#  'authserviceproxyservice_urlhttp0112700118081json_rpcformatusername',
#  'password',
#  '2',
#  'using',
#  'public',
#  'node',
#  'standard',
#  'public',
#  'node',
#  'seth',
#  'privacy',
#  'httpnodesethforprivacycom18089',
#  'change',
#  'connection',
#  'parameter',
#  'com_dbpy',
#  'according',
#  'need',
#  'running',
#  'mic',
#  'installing',
#  'required',
#  'package',
#  'simply',
#  'type',
#  'python3',
#  'micpy',
#  'contact',
#  'feel',
#  'free',
#  'reach',
#  'moneroinflationcheckerprotonmailcom',
#  'think',
#  'work',
#  'taught',
#  'something',
#  'want',
#  'see',
#  'growing',
#  'please',
#  'consider',
#  'donating',
#  '42abfi8jdqtjbbyuchip2flzscit6tkgh8nhxwvdjwyv4nbegdz85hrvf34h2ggu8k76ubep1mxz1vt4dbgkqnutqw9exhj',
#  'left_ventricle_inflation',
#  'left',
#  'ventricle',
#  'inflation',
#  'building',
#  'example',
#  'instruction',
#  'configure',
#  'build',
#  'cmake',
#  'git',
#  'clone',
#  'httpsgithubcomopencmissexamplesleft_ventricle_inflationgit',
#  'mkdir',
#  'build',
#  'cmake',
#  'dopencmisslibs_dirpathtoopencmisslibinstall',
#  'left_ventricle_inflation',
#  'make',
#  'cmake',
#  'build',
#  'also',
#  'work',
#  'much',
#  'platform',
#  'agnostic',
#  'running',
#  'example',
#  'explain',
#  'example',
#  'run',
#  'cd',
#  'build',
#  'srcfortranleft_ventricle_inflationf90',
#  'maybe',
#  'python',
#  'example',
#  'source',
#  'pathtoopencmisslibsinstallvirtaul_environmentsoclibs_venv_pyxy_releasebinactivate',
#  'python',
#  'srcpythonleft_ventricle_inflationpy',
#  'xy',
#  'path',
#  'python',
#  'major',
#  'minor',
#  'version',
#  'respectively',
#  'prerequisite',
#  'none',
#  'license',
#  'apache',
#  '20',
#  'license',
#  'zipregression',
#  'code',
#  'fixedeffect',
#  'zeroinflated',
#  'poisson',
#  'regression',
#  'model',
#  'code',
#  'part',
#  'work',
#  'prediction',
#  'sparse',
#  'useritem',
#  'consumption',
#  'rate',
#  'mean',
#  'academic',
#  'code',
#  ...]
